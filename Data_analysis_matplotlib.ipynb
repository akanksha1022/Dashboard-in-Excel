# %% [markdown]
# <a href="https://colab.research.google.com/github/akanksha1022/Dashboard-in-Excel/blob/main/Data_analysis_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x =np.linspace(0,5,11)
y= x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y,'r-')

# %%
plt.plot(x,y,'r--')

# %%
plt.plot (x,y,'r+')

# %%
plt.plot(x,y,'r*')

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'b')

# %%
fig=plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y)

# %%
fig=plt.figure()
axes1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])

# %%
fig=plt.figure()
asex1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])
axes1.plot(x,y,'b-')
axes2.plot(x,y,'r-')

# %%
axes1.set_title('my big plot')
axes2.set_title('my small plot')
# Out:
# Text(0.5, 1.0, 'my small plot')

# %%
fig=plt.figure()
asex1=fig.add_axes([0.1,0.1,0.8,0.8])
axes2=fig.add_axes([0.2,0.5,0.4,0.3])
axes1.plot(x,y,'b-')
axes1.set_title('my big plot')
axes2.plot(x,y,'r-')
axes2.set_title('my small plot')
# Out:
# Text(0.5, 1.0, 'my small plot')

# %%
fig,axes=plt.subplots(nrows=3,ncols=3)

# %%
fig,axes=plt.subplots(nrows=3,ncols=3)

plt.tight_layout()

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)

# %%
xaxes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
for curr_ax in axes:
  curr_ax.plot(x,y)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[1].plot(x,y)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[1].plot(y,x)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,x)
axes[1].plot(y,y)

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)
axes[0].plot(x,y)
axes[0].set_title("my first plot")
axes[1].plot(y,x)
axes[1].set_title("my second plot")
# Out:
# Text(0.5, 1.0, 'my second plot')

# %%
fig=plt.figure(figsize=(8,5))
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2)
ax.plot(x,x**3)
ax.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig=plt.figure(figsize=(8,5))
ax=fig.add_axes([0,0,1,1])
ax.plot(x,x**2)
ax.plot(x,x**3)
ax.legend(loc=1)
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
